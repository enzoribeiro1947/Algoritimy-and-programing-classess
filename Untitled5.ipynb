# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/Algoritimy-and-programing-classess/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PG aula
# *área

# %% [markdown]
# entrada:
# ler lado1
# ler lado2
#
# processamento:
# área = lado1 * lado2
#
# saida = resultado de lado1 * lado2

# %%
l1 = int(input("diga o lado um do seu quadrado "))
l2 = int(input("diga o segundo lado do seu quadrado "))
area = l1 * l2
print("a área do seu quadrado é:", area)
