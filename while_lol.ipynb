# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/Algoritimy-and-programing-classess/blob/main/while_lol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
opcao = 0

while opcao != 5:

    print("\n===== CALCULADORA =====")
    print("1 - Soma")
    print("2 - Subtração")
    print("3 - Multiplicação")
    print("4 - Divisão")
    print("5 - Sair")

    opcao = int(input("Digite uma opção: "))

    if opcao == 1:
        num1 = int(input("Digite o primeiro número: "))
        num2 = int(input("Digite o segundo número: "))

        print(f"{num1} + {num2} = {num1 + num2}")

    elif opcao == 2:
        num1 = int(input("Digite o primeiro número: "))
        num2 = int(input("Digite o segundo número: "))

        print(f"{num1} - {num2} = {num1 - num2}")

    elif opcao == 3:
        num1 = int(input("Digite o primeiro número: "))
        num2 = int(input("Digite o segundo número: "))

        print(f"{num1} x {num2} = {num1 * num2}")

    elif opcao == 4:
        num1 = int(input("Digite o primeiro número: "))
        num2 = int(input("Digite o segundo número: "))

        if num2 != 0:
            print(f"{num1} / {num2} = {num1 / num2}")
        else:
            print("Não existe divisão por zero")

    elif opcao == 5:
        print("Programa encerrado")

    else:
        print("Opção inválida")
# Out:
# digite uma opção de 1 a 5: 1
# digite um número: 2
# digite um número: 3
# 2 + 3 =
# 5
# digite uma opção de 1 a 5: 5
# programa encerrado

# %%
nota = int(input("qual a sua nota do bimestre"))
cont = 0

while nota > 10 or nota < 0:
