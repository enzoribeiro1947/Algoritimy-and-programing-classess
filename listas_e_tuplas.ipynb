# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/Algoritimy-and-programing-classess/blob/main/listas_e_tuplas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
frutas = ["maçã", "banana", "laranja", "morango"]

print(frutas)
# Out:
# ['leticia', 'anderson', 'marcos', 'rafaela']
# ['anderson', 'marcos', 'rafaela']

# %%
nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]

print(nomes[0])
print(nomes[1])
print(nomes[-1])

# %%
cores = ["vermelho", "azul", "verde"]

cores[1] = "amarelo"

print(cores)

# %%
alunos = ["Nicolas", "Wendel", "Pyetra"]

alunos.append("Petros")

print(alunos)

# %%
animais = ["cachorro", "gato", "coelho", "passarinho"]

animais.remove("coelho")

print(animais)

# %%
meses = ("Janeiro", "Fevereiro", "Março", "Abril")

print(meses)

# %%
numeros = (10, 20, 30, 40, 50)

print(numeros[0])
print(numeros[2])
print(numeros[-1])

# %%
aluno = ("Enzo", 16, "Informática para Internet")

print(aluno[0])
print(aluno[1])
print(aluno[2])

# %%
cores = ("vermelho", "azul", "verde")

cores[1] = "amarelo"

# %%
numeros = (2, 4, 2, 6, 2, 8, 10)

print(numeros.count(2))
