# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/Algoritimy-and-programing-classess/blob/main/aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = 16
print("idade:", idade, type(idade))

altura = 1.75
print("altura:", altura, type(altura))

numero_complexo = 24 + 69
print("numero_complexo:", numero_complexo, type(numero_complexo))

nome = "enzolollolpoggers"
print("nome:", nome, type(nome))

chuva = False
print("chuva:", chuva, type(chuva))

numeros = [1, 2, 3, 4, 5, 69, 24]
print("numeros:", numeros, type(numeros))

cordenadas_hehe = (10, 20)
print("cordenadas_hehe:", cordenadas_hehe, type(cordenadas_hehe))

teclas = {"w", "a", "s", "d"}
print("teclas:", teclas, type(teclas))

pessoa = {"danndann": "tudo", "idade": 13}
print("pessoa:", pessoa, type(pessoa))
# Out:
# idade: 16 <class 'int'>
# altura: 1.75 <class 'float'>
# numero_complexo: 93 <class 'int'>
# nome: enzolollolpoggers <class 'str'>
# chuva: False <class 'bool'>
# numeros: [1, 2, 3, 4, 5, 69, 24] <class 'list'>
# cordenadas_hehe: (10, 20) <class 'tuple'>
# teclas: {'a', 'w', 'd', 's'} <class 'set'>
# pessoa: {'danndann': 'tudo', 'idade': 13} <class 'dict'>
