# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoribeiro1947/Algoritimy-and-programing-classess/blob/main/atividade_def.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fazerCafe():
  print("preparando café")
  print("café pronto")

fazerCafe()
# Out:
# preparando café
# café pronto

# %%
def cumprimento(nome):
  print(f"olá {nome}")

cumprimento(str(input("Digite o seu nome: ")))
# Out:
# Digite o seu nome: sla
# olá sla

# %%
#1

def ola():
  print("ola mundo")

ola()

# %%
#2

def mensagem():
  print("Bem-vindo ao curso de programação!")

mensagem()

# %%
#3

def somar():
  print(f"30 + 2 = {30 + 2}")

somar()

# %%
#4

def subtrair():
  print(f"50 - 15 = {50 - 15}")

subtrair()
# Out:
# 50 - 15 = 35

# %%
#5

def multiplicar (a,b):
  print(f"{a} x {b} = {a*b}")

multiplicar(8,7)
# Out:
# 8 x 7 = 56

# %%
#6

def cumprimento(nome):
  print(f"olá {nome}")

cumprimento(str(input("Digite o seu nome: ")))

# %%
#7

def dobro(num):
  print(num * 2)

dobro(input("digite um número: "))

# %%
#8

def idade(num):
  print(f"você tem {num} anos")

idade(int(input("digite sua idade")))

# %%
#9

def verificarnumero(num):
  if num < 0:
    print("o número é negativo")
  elif num > 0:
    print("o número é positivo")
  else:
    print("o número é 0")

verificarnumero(int(input("digite um número: ")))

# %%
#10

def media(nota1, nota2):
  print((nota1 + nota2) / 2)

media(float(input("digite a nota 1: ")), float(input("digite a nota 2: ")))
# Out:
# digite a nota1: 2
# digite a nota2: 2
# 2.0
